# %%
from stocknn.data_pipeline.ingest import TickerData
import polars as pd
df = TickerData()
df = pd.DataFrame(df)

df.describe()

df['(\'Date\', \'\')']
# Out:
# /Users/haltane/Desktop/Projects/stockNN/src/stocknn/data_pipeline/ingest.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start_date, end=end_date, interval=interval)
# [*********************100%***********************]  1 of 1 completed
# shape: (1_136,)
# Series: '('Date', '')' [datetime[ns]]
# [
# 	2022-01-03 00:00:00
# 	2022-01-04 00:00:00
# 	2022-01-05 00:00:00
# 	2022-01-06 00:00:00
# 	2022-01-07 00:00:00
# 	…
# 	2026-07-09 00:00:00
# 	2026-07-10 00:00:00
# 	2026-07-13 00:00:00
# 	2026-07-14 00:00:00
# 	2026-07-15 00:00:00
# ]

# %%
import matplotlib.pyplot as plt

plt.plot(df[Close], label='Close')
plt.ylabel('Price')
plt.show()
